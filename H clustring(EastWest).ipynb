# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("EastWestAirlines.xlsx",  sheet_name='data')

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.shape
# Out:
# (3999, 12)

# %%
## first we can normalize the data

# %%
def norm (i):
    x= (i - i.min()) / (i.max() - i.min())
    return x

# %%
norm = norm(df)

# %%
norm.head()
# Out:
#         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0  0.000000  0.016508         0.0       0.00        0.0        0.0
# 1  0.000249  0.011288         0.0       0.00        0.0        0.0
# 2  0.000498  0.024257         0.0       0.00        0.0        0.0
# 3  0.000746  0.008667         0.0       0.00        0.0        0.0
# 4  0.000995  0.057338         0.0       0.75        0.0        0.0
#
#    Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0     0.000660     0.011628           0.000000         0.000000
# 1     0.000815     0.023256           0.000000         0.000000
# 2     0.015636     0.046512           0.000000         0.000000
# 3     0.001896     0.011628           0.000000         0.000000
# 4     0.164211     0.302326           0.067398         0.075472
#
#    Days_since_enroll  Award?
# 0           0.843742     0.0
# 1           0.839884     0.0
# 2           0.847842     0.0
# 3           0.837955     0.0
# ...

# %%
## norm make the dentrogram / make the clusters
import scipy.cluster.hierarchy as sch

# %%
##dendrogram = sch.dendrogram(sch.linkage(norm, method='single'))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='single')

# %%
prid = model.fit_predict(norm)

# %%
prid[:10]
# Out:
# array([2, 2, 2, 2, 0, 2, 2, 0, 0, 0], dtype=int64)

# %%
df["Cluster"] = prid

# %%
df[:20]
# Out:
#     ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     1    28143           0          1          1          1          174
# 1     2    19244           0          1          1          1          215
# 2     3    41354           0          1          1          1         4123
# 3     4    14776           0          1          1          1          500
# 4     5    97752           0          4          1          1        43300
# 5     6    16420           0          1          1          1            0
# 6     7    84914           0          3          1          1        27482
# 7     8    20856           0          1          1          1         5250
# 8     9   443003           0          3          2          1         1753
# 9    10   104860           0          3          1          1        28426
# 10   11    40091           0          2          1          1         7278
# ...
